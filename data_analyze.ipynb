# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4])#x좌표가 1부터 시작
plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4], 'ro')#ro -> bv 수정해보기
plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4], 'r-',[1,2,3,4],[3,4,5,6], 'v-')

# %%
plt.plot([1,2,3,4])
plt.xlabel('x축 한글표시')
plt.show()
# Out:
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from matplotlib import font_manager, rc
import matplotlib
font_location = "c:/Windows/Fonts/KoPubDotum.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
plt.plot([1,2,3,4])
plt.xlabel('x축 한글표시')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-f3f13c937552> in <module>
#       2 import matplotlib
#       3 font_location = "c:/Windows/Fonts/KoPubDotum.ttf"
# ----> 4 font_name = font_manager.FontProperties(fname=font_location).get_name()
#       5 matplotlib.rc('font', family=font_name)
#       6 plt.plot([1,2,3,4])
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\font_manager.py in get_name(self)
#     760         Return the name of the font that best matches the font properties.
#     761         """
# --> 762         return get_font(findfont(self)).family_name
#     763
#     764     def get_style(self):
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1415     if hinting_factor is None:
#    1416         hinting_factor = rcParams['text.hinting_factor']
# ...

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot([1,2,3,4], [1,2,3,4])
plt.subplot(2,1,2)
plt.plot([5,6,7,8],[5,6,7,8])
plt.show()
plt.figure()
plt.subplot(1, 2, 1)
plt.plot([10,20,30,40], [1,2,3,4])
plt.subplot(1,2,2)
plt.plot([50,60,70,80],[5,6,7,8])
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('차트 제목')
plt.text(3.5, 30.0, '평균:2.5')
plt.grid(True)
plt.show()
# Out:
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hjand\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from konlpy.tag import _hannanum

# %%
hannanum =  _hannanum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a7ff04cc2bad> in <module>
# ----> 1 hannanum =  _hannanum()
#
# TypeError: 'module' object is not callable
