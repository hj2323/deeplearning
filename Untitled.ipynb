# %%
import numpy as np
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD

# %%
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# %%
tf.model = Sequential()

# %%
tf.model.add(Flatten())
tf.model.add(Dense(5, input_dim=4, activation='relu'))

# %%
tf.model.add(Dense(4, activation='relu'))
tf.model.add(Dense(1))

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1) # SGD

# %%
tf.model.compile(optimizer='sgd',loss='mse')

# %%
tf.model.fit(x_train, y_train, epochs=200)
y_predict = tf.model.predict(np.array([5, 4]))
print(y_predict)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 499ms/step - loss: 3.4920
# Epoch 2/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3893
# Epoch 3/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2913
# Epoch 4/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1976
# Epoch 5/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1079
# Epoch 6/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0222
# Epoch 7/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9402
# Epoch 8/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8617
# Epoch 9/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7865
# Epoch 10/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7144
# Epoch 11/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6452
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5789
# ...
